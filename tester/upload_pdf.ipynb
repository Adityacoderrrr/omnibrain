# %% [markdown]
# # pfd upload testing

# %%
# Cell 1: Install dependencies (run once)
# !pip install pymupdf sentence-transformers faiss-cpu python-docx

# %%
# Cell 2: Import libraries
import fitz
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
filename = r"C:\Users\riche\Downloads\ML Cycle Real World Example.pdf"

# %%
import fitz

filename = r"C:\Users\riche\Downloads\ML Cycle Real World Example.pdf"

pdf = fitz.open(filename)

text = ""

for page in pdf:
    text += page.get_text()

pdf.close()

print(text[:1000])
# Out:
# Real-World Example: Traffic Prediction
# Let’s say we want to predict traffic congestion in a city to help with route
# planning or traffic signal control.
#
# 1. Problem Definition
# • Goal: Predict the level of traffic congestion (e.g., low, medium, high) or
# travel time on a specific route.
# • Type: Supervised learning (Classification or Regression, depending on
# output type).
#
# 2. Data Collection
# • Sources of data:
# o GPS data from vehicles
# o Road sensors and traffic cameras
# o Mobile app data (like Google Maps or Waze)
# o Weather and event data
# o Historical traffic data
#
# 3. Data Preprocessing
# • Handle missing values (e.g., sensor outages).
# • Remove noise or outliers (e.g., impossible speeds).
# • Convert timestamps to useful features (day, hour, weekday).
# • Normalize features (e.g., travel time, speed).
#
#
#
# 4. Feature Engineering
# • Create features like:
# o Time of day, day of week
# o Weather conditions (rain, fog, etc.)
# o Road type and location
# ...
